# %% [markdown]
# $$Conceitos:$$
#
# - **Camadas de entrada não pode ser menor do que a quantidade de variáveis que estamos usando para explicar Y**
#
#
# - **Deep Learning** = Arquitetura da Rede Neural
#
#
# - **Redes neurais rasas (shallow)** = Possui apenas uma camada oculta
#
#
# - **Redes neurais profundas** = Quando as redes neurais possuem muitas camadas ocultas, trata-se de deep learning.
#
#
# - **Função de ativação** =
#
#
# - **Função de Custo** = Função que mensura o quanto estamos acertando
#
#
# - **Epocas** =
#
#
# - **Descida do gradiente** = Processo utilizado para encontrar o mínimo da função custo com base em variação nos pesos, através do processo de backpropagation os erros obtidos após os cálculos dos pesos são retroalimentados na rede até otimizarmos o resultado
#
#
# **Tipos de Modelos de Redes Neurais:**
#
#
# - **Perceptron (P), Feed Forward Network (FFN), Radial Basis Network (RBF)** = São o tipo mais básico, onde a informação de entrada flui em sequência linear até a saída.

# %%
#Importar as bibliotecas
import numpy as np
import pandas as pd

# %% [markdown]
# ## Carregando o dataset

# %%
#Carregar dataset
dados = pd.read_csv('winequality-red.csv',encoding='latin1',sep=',')
dados
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
#Separar os dados em X e Y
x = dados.iloc[:,0:11]
y = dados.quality

#Padronização dos dados

dados_padro = (x - x.mean()) / (x.std())
dados_padro
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.528194          0.961576    -1.391037       -0.453077  -0.243630
# 1         -0.298454          1.966827    -1.391037        0.043403   0.223805
# 2         -0.298454          1.296660    -1.185699       -0.169374   0.096323
# 3          1.654339         -1.384011     1.483689       -0.453077  -0.264878
# 4         -0.528194          0.961576    -1.391037       -0.453077  -0.243630
# ...             ...               ...          ...             ...        ...
# 1594      -1.217415          0.403103    -0.980362       -0.382151   0.053829
# 1595      -1.389721          0.123866    -0.877693       -0.240300  -0.541090
# 1596      -1.159980         -0.099523    -0.723690       -0.169374  -0.243630
# 1597      -1.389721          0.654416    -0.775024       -0.382151  -0.264878
# 1598      -1.332285         -1.216469     1.021680        0.752659  -0.434854
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0               -0.466047             -0.379014  0.558100  1.288240
# 1                0.872365              0.624168  0.028252 -0.719708
# 2               -0.083643              0.228975  0.134222 -0.331073
# 3                0.107558              0.411372  0.664069 -0.978798
# 4               -0.466047             -0.379014  0.558100  1.288240
# ...                   ...                   ...       ...       ...
# 1594             1.541571             -0.075020 -0.978459  0.899605
# 1595             2.210777              0.137777 -0.861893  1.353012
# 1596             1.254769             -0.196617 -0.533387  0.705287
# 1597             1.541571             -0.075020 -0.676446  1.676875
# 1598             0.203159             -0.135818 -0.665849  0.510970
#
#       sulphates   alcohol
# 0     -0.579025 -0.959946
# 1      0.128910 -0.584594
# 2     -0.048074 -0.584594
# 3     -0.461036 -0.584594
# 4     -0.579025 -0.959946
# ...         ...       ...
# 1594  -0.461036  0.072271
# 1595   0.600867  0.729136
# 1596   0.541872  0.541460
# 1597   0.305894 -0.209243
# 1598   0.010921  0.541460
#
# [1599 rows x 11 columns]

# %%
#Divisão dos dados 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dados_padro,y,test_size=0.3,random_state=1)

#Alterar as dimensoes
X_train = X_train.T
X_test = X_test.T
y_train = pd.DataFrame(y_train).T
y_test = pd.DataFrame(y_test).T

# %%
#Função sigmoid    
def sig(x):
    return((1/(1+np.exp(-x))))

# %%
class Total:  
#Iniciar os parametros da rede    
    def __init__(self,x,y,hidden_neurons,lr,num_iteration):


        self.x = x
        self.y = y
        self.hidden_neurons = hidden_neurons
        self.lr = lr
        self.num_iteration = num_iteration


    #Arquitetura da rede
    def arq_rede(self):
        n_x = self.x.shape[0]
        n_h = self.hidden_neurons
        n_y = self.y.shape[0]
        arquite = {'n_x': n_x, 'n_h': n_h, 'n_y': n_y}
        return(arquite)

#Inicializar pesos
    def init_pesos(self):
        n_x = self.arq_rede().get('n_x')
        n_h = self.arq_rede().get('n_h')
        n_y = self.arq_rede().get('n_y')
        W1 = np.full((n_h, n_x), np.random.uniform(0,n_h * n_x))*0.01
        W2 = np.full((n_y, n_h), np.random.uniform(0,n_h * n_x))*0.01
        params_pesos = {'W1': W1, 'W2': W2}
        return(params_pesos)


#Forward Propagation

    def forward_prop(self):

        n_h = self.arq_rede().get('n_x')
        n_y = self.arq_rede().get('n_y')

        W1 = self.init_pesos().get('W1')
        W2 = self.init_pesos().get('W2')


        Z1 = np.dot(W1,self.x) #Multiplicação entre camada de entrada X Pesos
        A1 = sig(Z1) #Função Sigmoide do resultado da Multiplicação entre Camada de entrada X Pesos (Camada Oculta)
        Z2 = np.dot(W2,A1) #Multiplicação entre o resultado da sigmoide X pesos da camada intermediaria (Entre camada oculta e saida)
        prev1 = sig(Z2) #Função Sigmoide no resultado da multiplicação de Z2 (Camada de saida)
        cache = {'Z1':W1, 'A1':A1, 'Z2':Z2, 'prev1':prev1}
        return (cache)

#Cost Function

    def funcao_custo(self):

        m = self.y.shape[1]
        prev1 = self.forward_prop().get('prev1')
        target =self.y.values[0]

        self.cost = sum(sum((target - prev1)**2))/m
        return (self.cost)

#Backpropagation
    def backwardPropagation(self):

        m = self.y.shape[1]

        n_x = self.arq_rede().get('n_x')
        n_h = self.arq_rede().get('n_h')
        n_y = self.arq_rede().get('n_y')

        prev1 = self.forward_prop().get('prev1')
        A1 = self.forward_prop().get('A1')
        W2 = self.init_pesos().get('W2')


        dZ2 = self.forward_prop().get('prev1') - self.y #Valor previsto - Valor real (Diferença para alterar os pesos)
        dW2 = 1/m * np.dot(dZ2, A1.T) #Quanto eu preciso alterar os pesos de W2


        dZ1 = np.dot(W2.T,dZ2) * (1 - A1**2)#Mudança que ocorre na camada intermediaria para camada de entrada em funçao de DZ2
        dW1 = 1/m * np.dot(dZ1 , self.x.T) #Quanto eu preciso alterar os pesos de W1 em função de W2


        grads = {'dW1':dW1, 'dW2':dW2}


        return(grads)

#Atualizar os pesos
    def updateParameters(self):

        W1 = self.init_pesos().get('W1')
        W2 = self.init_pesos().get('W2')

        dW1 = self.backwardPropagation().get('dW1')
        dW2 = self.backwardPropagation().get('dW2')


        W1 = W1 - self.lr * dW1 #Atualizar peso W1
        W2 = W2 - self.lr * dW2 #Atualizar peso W2

        updated_pesos = {'W1': W1, 'W2': W2}



        return(updated_pesos)

#loop

    def loop(self):
        Total.updateParameters(self)
        Total.forward_prop(self)
        c=Total.funcao_custo(self)
        while c > 22:
            Total.funcao_custo(self)
            Total.backwardPropagation(self)
            Total.updateParameters(self)
            Total.forward_prop(self)
            cc=Total.funcao_custo(self)
            print(cc)

# %%
#Inicialização dos hiperparametros

init_pesos1 = Total(x = X_train,y = y_train,hidden_neurons = 2,lr = 0.1, num_iteration=10)
init_pesos1

# %%
#Inicializar pesos
init_pesos1.arq_rede()
# Out:
# {'n_x': 11, 'n_h': 2, 'n_y': 1}

# %%
#Forward Propagation
a =init_pesos1.forward_prop()
a
# Out:
# {'Z1': array([[0.02132089, 0.02132089, 0.02132089, 0.02132089, 0.02132089,
#          0.02132089, 0.02132089, 0.02132089, 0.02132089, 0.02132089,
#          0.02132089],
#         [0.02132089, 0.02132089, 0.02132089, 0.02132089, 0.02132089,
#          0.02132089, 0.02132089, 0.02132089, 0.02132089, 0.02132089,
#          0.02132089]]),
#  'A1': array([[0.50372554, 0.46873294, 0.48591527, ..., 0.49929987, 0.48101336,
#          0.49262724],
#         [0.50372554, 0.46873294, 0.48591527, ..., 0.49929987, 0.48101336,
#          0.49262724]]),
#  'Z2': array([[0.1004862 , 0.09350566, 0.0969333 , ..., 0.09960334, 0.09595544,
#          0.09827224]]),
#  'prev1': array([[0.52510043, 0.5233594 , 0.52421437, ..., 0.52488027, 0.52397047,
#          0.52454831]])}

# %%
#Cost Function
init_pesos1.funcao_custo()
# Out:
# 26.759194290542155

# %%
#Backpropagation
init_pesos1.backwardPropagation()
# Out:
# {'dW1': array([[ 0.06939445,  0.0406938 ,  0.07522523,  0.09893194,  0.08393549,
#           0.10104048,  0.1266208 ,  0.12905999, -0.04850266,  0.05184578,
#          -0.06494438],
#         [ 0.06939445,  0.0406938 ,  0.07522523,  0.09893194,  0.08393549,
#           0.10104048,  0.1266208 ,  0.12905999, -0.04850266,  0.05184578,
#          -0.06494438]]),
#  'dW2': array([[-2.55341468, -2.55341468]])}

# %%
#Atualizar os pesos
init_pesos1.updateParameters()
# Out:
# {'W1': array([[0.03914904, 0.03914904, 0.03914904, 0.03914904, 0.03914904,
#          0.03914904, 0.03914904, 0.03914904, 0.03914904, 0.03914904,
#          0.03914904],
#         [0.03914904, 0.03914904, 0.03914904, 0.03914904, 0.03914904,
#          0.03914904, 0.03914904, 0.03914904, 0.03914904, 0.03914904,
#          0.03914904]]),
#  'W2': array([[0.14476492, 0.14476492]])}

# %%
init_pesos1.loop()
# Out:
# 26.920583668216633
# 26.922416135915565
# 26.808366260052743
# 27.07879799582452
# 26.7106566349618
# 27.12668044311143
# 27.121378201970877
# 27.09013820945573
# 26.98562471581236
# 26.77405765625355
# 26.847927168249008
# 27.16822837381555
# 27.17970404050511
# 26.748186389193897
# 26.936757080589125
# 27.154587870982073
# 27.186111353964804
# 27.157760901925414
# 27.164387633550646
# 27.210771504784322
# 27.08687822518459
# 27.145327363179533
# 26.753605232183514
# 27.119981852072495
# 27.14293134378053
# 27.227791312028085
# 26.839526026657012
# 26.81873819179959
# 26.724265858315814
# 26.975106495990428
# 27.004519551372802
# 26.825838962929144
# 27.23458365720594
# 26.712818082072477
# 27.183262689502353
# 27.125524351454633
# 26.734194824536445
# 26.71694036028158
# 26.965263183081767
# 27.21154306402206
# 27.192192780178935
# 27.08856282720573
# 26.709405918210983
# 27.132190666174104
# 27.09288392800838
# 26.836638949696955
# 26.89555665224132
# 27.00383584646601
# 26.887601174091586
# 27.23719004007806
# 27.112195745450254
# 26.704341411429166
# 26.860141932499822
# 26.8511693337131
# 27.044637743644344
# 26.727797531680107
# 27.148795189996015
# 26.805251025975906
# 26.851233527754538
# 26.931647501284417
# 27.143837768758193
# 27.16270664715138
# 27.091752644212757
# 26.928336090909312
# 26.74140573538522
# 27.132070241524374
# 26.869301053658585
# 27.093222863511606
# 27.241167986885
# 27.094548085928942
# 27.033897298804277
# 27.038418292859504
# 27.030287651521984
# 27.050754775871162
# 27.033884572080193
# 26.695595831982054
# 26.83924109127127
# 26.695046027406264
# 27.23711520858003
# 27.22142916439565
# 26.960004523523747
# 26.902633135485043
# 26.78371916039005
# 27.037181730415604
# 27.11543957536535
# 26.952862841800236
# 27.190693271809703
# 26.74934460573523
# 26.990955795401998
# 27.1737911148603
# 27.24555573307152
# 26.71714700833374
# 26.8343000998934
# 27.093220166321302
# 26.811379888578386
# 26.732630005703953
# 27.092358446828918
# 26.95782181044834
# 26.864979096274816
# 26.86179169327101
# 26.945045191636698
# 27.07055639754692
# 26.719821697222365
# 27.150086220848156
# 27.199925638283347
# 27.010246894544963
# 27.1390971304672
# 27.01629810223871
# 26.73295786813183
# 26.77236501870872
# 27.243182201031345
# 26.86854460623671
# 26.770599586197136
# 27.236911207754805
# 26.77643014839777
# 27.059477899489252
# 26.91241961263829
# 26.99183316779481
# 26.868044582894665
# 27.07451599294883
# 26.913460965862683
# 26.710888896227935
# 26.936077645968485
# 27.152492501472622
# 26.786914057771032
# 27.015315286036067
# 26.766701078592803
# 27.159112240292135
# 27.215066303702002
# 27.063388855651198
# 26.73042612354108
# 27.028794864102668
# 27.22907350140508
# 26.943604022086987
# 27.219598611081732
# 26.95049248586666
# 27.061591711586132
# 27.131099321860617
# 26.986645968882442
# 26.927352378199544
# 27.07247853850046
# 27.205755041443982
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9404/886944569.py in <module>
# ----> 1 init_pesos1.loop()
#
# ~\AppData\Local\Temp/ipykernel_9404/2107982094.py in loop(self)
#     114             Total.funcao_custo(self)
#     115             Total.backwardPropagation(self)
# --> 116             Total.updateParameters(self)
#     117             Total.forward_prop(self)
#     118             cc=Total.funcao_custo(self)
#
# ~\AppData\Local\Temp/ipykernel_9404/2107982094.py in updateParameters(self)
#      92         W2 = self.init_pesos().get('W2')
#      93
# ---> 94         dW1 = self.backwardPropagation().get('dW1')
#      95         dW2 = self.backwardPropagation().get('dW2')
#      96
#
# ~\AppData\Local\Temp/ipykernel_9404/2107982094.py in backwardPropagation(self)
#      69
#      70         prev1 = self.forward_prop().get('prev1')
# ---> 71         A1 = self.forward_prop().get('A1')
#      72         W2 = self.init_pesos().get('W2')
#      73
#
# ~\AppData\Local\Temp/ipykernel_9404/2107982094.py in forward_prop(self)
#      41
#      42
# ---> 43         Z1 = np.dot(W1,self.x) #Multiplicação entre camada de entrada X Pesos
#      44         A1 = sig(Z1) #Função Sigmoide do resultado da Multiplicação entre Camada de entrada X Pesos (Camada Oculta)
#      45         Z2 = np.dot(W2,A1) #Multiplicação entre o resultado da sigmoide X pesos da camada intermediaria (Entre camada oculta e saida)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:
