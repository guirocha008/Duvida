# %% [markdown]
# $$Conceitos:$$
#
# - **Camadas de entrada não pode ser menor do que a quantidade de variáveis que estamos usando para explicar Y**
#
#
# - **Deep Learning** = Arquitetura da Rede Neural
#
#
# - **Redes neurais rasas (shallow)** = Possui apenas uma camada oculta
#
#
# - **Redes neurais profundas** = Quando as redes neurais possuem muitas camadas ocultas, trata-se de deep learning.
#
#
# - **Função de ativação** =
#
#
# - **Função de Custo** = Função que mensura o quanto estamos acertando
#
#
# - **Epocas** =
#
#
# - **Descida do gradiente** = Processo utilizado para encontrar o mínimo da função custo com base em variação nos pesos, através do processo de backpropagation os erros obtidos após os cálculos dos pesos são retroalimentados na rede até otimizarmos o resultado
#
#
# **Tipos de Modelos de Redes Neurais:**
#
#
# - **Perceptron (P), Feed Forward Network (FFN), Radial Basis Network (RBF)** = São o tipo mais básico, onde a informação de entrada flui em sequência linear até a saída.

# %%
#Importar as bibliotecas
import numpy as np
import pandas as pd

# %% [markdown]
# ## Carregando o dataset

# %%
#Carregar dataset
dados = pd.read_csv('winequality-red.csv',encoding='latin1',sep=',')
dados
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
#Separar os dados em X e Y
x = dados.iloc[:,0:11]
y = dados.quality

#Padronização dos dados

dados_padro = (x - x.mean()) / (x.std())
dados_padro
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.528194          0.961576    -1.391037       -0.453077  -0.243630
# 1         -0.298454          1.966827    -1.391037        0.043403   0.223805
# 2         -0.298454          1.296660    -1.185699       -0.169374   0.096323
# 3          1.654339         -1.384011     1.483689       -0.453077  -0.264878
# 4         -0.528194          0.961576    -1.391037       -0.453077  -0.243630
# ...             ...               ...          ...             ...        ...
# 1594      -1.217415          0.403103    -0.980362       -0.382151   0.053829
# 1595      -1.389721          0.123866    -0.877693       -0.240300  -0.541090
# 1596      -1.159980         -0.099523    -0.723690       -0.169374  -0.243630
# 1597      -1.389721          0.654416    -0.775024       -0.382151  -0.264878
# 1598      -1.332285         -1.216469     1.021680        0.752659  -0.434854
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0               -0.466047             -0.379014  0.558100  1.288240
# 1                0.872365              0.624168  0.028252 -0.719708
# 2               -0.083643              0.228975  0.134222 -0.331073
# 3                0.107558              0.411372  0.664069 -0.978798
# 4               -0.466047             -0.379014  0.558100  1.288240
# ...                   ...                   ...       ...       ...
# 1594             1.541571             -0.075020 -0.978459  0.899605
# 1595             2.210777              0.137777 -0.861893  1.353012
# 1596             1.254769             -0.196617 -0.533387  0.705287
# 1597             1.541571             -0.075020 -0.676446  1.676875
# 1598             0.203159             -0.135818 -0.665849  0.510970
#
#       sulphates   alcohol
# 0     -0.579025 -0.959946
# 1      0.128910 -0.584594
# 2     -0.048074 -0.584594
# 3     -0.461036 -0.584594
# 4     -0.579025 -0.959946
# ...         ...       ...
# 1594  -0.461036  0.072271
# 1595   0.600867  0.729136
# 1596   0.541872  0.541460
# 1597   0.305894 -0.209243
# 1598   0.010921  0.541460
#
# [1599 rows x 11 columns]

# %%
#Divisão dos dados 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dados_padro,y,test_size=0.3,random_state=1)

#Alterar as dimensoes
X_train = X_train.T
X_test = X_test.T
y_train = pd.DataFrame(y_train).T
y_test = pd.DataFrame(y_test).T

# %%
#Função sigmoid    
def sig(x):
    return((1/(1+np.exp(-x))))

# %%
class Total:  
#Iniciar os parametros da rede    
    def __init__(self,x,y,hidden_neurons,lr,num_iteration):


        self.x = x
        self.y = y
        self.hidden_neurons = hidden_neurons
        self.lr = lr
        self.num_iteration = num_iteration


    #Arquitetura da rede
    def arq_rede(self):
        n_x = self.x.shape[0]
        n_h = self.hidden_neurons
        n_y = self.y.shape[0]
        arquite = {'n_x': n_x, 'n_h': n_h, 'n_y': n_y}
        return(arquite)

#Inicializar pesos
    def init_pesos(self):
        n_x = self.arq_rede().get('n_x')
        n_h = self.arq_rede().get('n_h')
        n_y = self.arq_rede().get('n_y')
        W1 = np.full((n_h, n_x), np.random.uniform(0,n_h * n_x))*0.01
        W2 = np.full((n_y, n_h), np.random.uniform(0,n_h * n_x))*0.01
        params_pesos = {'W1': W1, 'W2': W2}
        return(params_pesos)


#Forward Propagation

    def forward_prop(self):

        n_h = self.arq_rede().get('n_x')
        n_y = self.arq_rede().get('n_y')

        W1 = self.init_pesos().get('W1')
        W2 = self.init_pesos().get('W2')


        Z1 = np.dot(W1,self.x) #Multiplicação entre camada de entrada X Pesos
        A1 = sig(Z1) #Função Sigmoide do resultado da Multiplicação entre Camada de entrada X Pesos (Camada Oculta)
        Z2 = np.dot(W2,A1) #Multiplicação entre o resultado da sigmoide X pesos da camada intermediaria (Entre camada oculta e saida)
        prev1 = sig(Z2) #Função Sigmoide no resultado da multiplicação de Z2 (Camada de saida)
        cache = {'Z1':W1, 'A1':A1, 'Z2':Z2, 'prev1':prev1}
        return (cache)

#Cost Function

    def funcao_custo(self):

        m = self.y.shape[1]
        prev1 = self.forward_prop().get('prev1')
        target =self.y.values[0]

        self.cost = sum(sum((target - prev1)**2))/m
        return (self.cost)

#Backpropagation
    def backwardPropagation(self):

        m = self.x.shape[1]

        n_x = self.arq_rede().get('n_x')
        n_h = self.arq_rede().get('n_h')
        n_y = self.arq_rede().get('n_y')

        prev1 = self.forward_prop().get('prev1')
        A1 = self.forward_prop().get('A1')
        W2 = self.init_pesos().get('W2')
        target =self.y.values[0]



        dZ2 = (prev1 - target) #Valor previsto - Valor real (Diferença para alterar os pesos)
        dW2 = 1/m * np.dot(dZ2, A1.T) #Quanto eu preciso alterar os pesos de W2


        dZ1 = np.dot(W2.T,dZ2) * (1 - A1**2)#Mudança que ocorre na camada intermediaria para camada de entrada em funçao de DZ2
        dW1 = 1/m * np.dot(dZ1 , self.x.T) #Quanto eu preciso alterar os pesos de W1 em função de W2


        grads = {'dW1':dW1, 'dW2':dW2}


        return(grads)

#Atualizar os pesos
    def updateParameters(self):

        W1 = self.init_pesos().get('W1')
        W2 = self.init_pesos().get('W2')

        dW1 = self.backwardPropagation().get('dW1')
        dW2 = self.backwardPropagation().get('dW2')


        W1 = W1 - self.lr * dW1 #Atualizar peso W1
        W2 = W2 - self.lr * dW2 #Atualizar peso W2

        updated_pesos = {'W1': W1, 'W2': W2}



        return(updated_pesos)

#loop

    def loop(self):
        Total.updateParameters(self)
        Total.forward_prop(self)
        c=Total.funcao_custo(self)
        while c > 26.6:
            
            Total.backwardPropagation(self)
            Total.updateParameters(self)
            Total.forward_prop(self)
            c=Total.funcao_custo(self)
            print(c)

# %%
#Inicialização dos hiperparametros

init_pesos1 = Total(x = X_train,y = y_train,hidden_neurons = 2,lr = 0.1, num_iteration=10)
init_pesos1

# %%
init_pesos1.teste()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9404/2174757757.py in <module>
# ----> 1 init_pesos1.teste()
#
# AttributeError: 'Total' object has no attribute 'teste'

# %%
#Inicializar pesos
init_pesos1.arq_rede()
# Out:
# {'n_x': 11, 'n_h': 2, 'n_y': 1}

# %%
#Forward Propagation
a =init_pesos1.forward_prop()
a
# Out:
# {'Z1': array([[0.00714571, 0.00714571, 0.00714571, 0.00714571, 0.00714571,
#          0.00714571, 0.00714571, 0.00714571, 0.00714571, 0.00714571,
#          0.00714571],
#         [0.00714571, 0.00714571, 0.00714571, 0.00714571, 0.00714571,
#          0.00714571, 0.00714571, 0.00714571, 0.00714571, 0.00714571,
#          0.00714571]]),
#  'A1': array([[0.50124864, 0.48950868, 0.49527838, ..., 0.49976535, 0.4936339 ,
#          0.49752886],
#         [0.50124864, 0.48950868, 0.49527838, ..., 0.49976535, 0.4936339 ,
#          0.49752886]]),
#  'Z2': array([[0.12577167, 0.12282592, 0.12427363, ..., 0.12539949, 0.123861  ,
#          0.12483831]]),
#  'prev1': array([[0.53140153, 0.53066793, 0.53102848, ..., 0.53130885, 0.53092572,
#          0.53116911]])}

# %%
#Cost Function
init_pesos1.funcao_custo()
# Out:
# 26.737139203266977

# %%
#Backpropagation
init_pesos1.backwardPropagation()
# Out:
# {'dW1': array([[ 0.00110974,  0.01230565,  0.0012025 ,  0.00935416,  0.00966324,
#           0.01480611,  0.02110712,  0.01637169, -0.00506216, -0.00478311,
#          -0.02387373],
#         [ 0.00110974,  0.01230565,  0.0012025 ,  0.00935416,  0.00966324,
#           0.01480611,  0.02110712,  0.01637169, -0.00506216, -0.00478311,
#          -0.02387373]]),
#  'dW2': array([[-2.57028077, -2.57028077]])}

# %%
#Atualizar os pesos
init_pesos1.updateParameters()
# Out:
# {'W1': array([[0.16975507, 0.16943016, 0.16941087, 0.16686592, 0.1675674 ,
#          0.16600712, 0.1638146 , 0.16444257, 0.17649216, 0.17137423,
#          0.18013478],
#         [0.16975507, 0.16943016, 0.16941087, 0.16686592, 0.1675674 ,
#          0.16600712, 0.1638146 , 0.16444257, 0.17649216, 0.17137423,
#          0.18013478]]),
#  'W2': array([[0.36775659, 0.36775659]])}

# %%
init_pesos1.loop()
# Out:
# 27.154389909139937
# 26.728328141629248
# 26.7305333799829
# 26.946587659540207
# 27.22289656459034
# 27.174616995412634
# 27.193920901846603
# 27.18528766805744
# 27.188125129458935
# 26.918971855099333
# 27.218433280171904
# 26.89588507089413
# 26.819101510579667
# 27.185360113578675
# 27.046624531904456
# 26.925862176387696
# 26.985195082349502
# 26.901545809526944
# 27.118107654751384
# 27.017235690267036
# 26.832737109609816
# 26.75203423528123
# 27.192317959468916
# 26.699076866789323
# 26.825208622099098
# 26.845954137264815
# 26.73970888882065
# 26.893794671455485
# 26.71048209650477
# 26.960880279841884
# 27.137696167436893
# 27.129765672437234
# 27.22029463438803
# 27.229095226013488
# 26.92085413469611
# 27.135218235707438
# 27.23667812582749
# 26.943596926147038
# 27.06024925685838
# 26.93078134607083
# 26.90341346937087
# 27.235938333014552
# 26.76900934504355
# 27.173535832581106
# 27.11707237883579
# 26.995775942056678
# 26.694166586218433
# 27.151736998602406
# 27.11566356657313
# 26.719760879092426
# 27.007870040435478
# 27.158110187048425
# 27.144853076211014
# 26.747813524186036
# 26.83665528813957
# 27.050976503051235
# 26.985729650554884
# 27.16051587070297
# 26.998277385357586
# 26.90993503550244
# 27.245306920422205
# 26.887810756952213
# 26.701620851520406
# 27.144644349426173
# 27.094254589765768
# 27.182378760664047
# 27.060284249417734
# 27.061242258198178
# 26.694991957587575
# 26.709602481692798
# 26.977926927287875
# 27.24021841313533
# 26.820147849521415
# 27.03114785601617
# 26.895919492144333
# 26.882988876126902
# 27.017070234522564
# 27.21805843067251
# 26.956702222711318
# 26.738087794646336
# 26.82536692268651
# 27.134976163191382
# 26.80906206962052
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9404/886944569.py in <module>
# ----> 1 init_pesos1.loop()
#
# ~\AppData\Local\Temp/ipykernel_9404/191231660.py in loop(self)
#     115         while c > 26.6:
#     116
# --> 117             Total.backwardPropagation(self)
#     118             Total.updateParameters(self)
#     119             Total.forward_prop(self)
#
# ~\AppData\Local\Temp/ipykernel_9404/191231660.py in backwardPropagation(self)
#      75
#      76
# ---> 77         dZ2 = (prev1 - target) #Valor previsto - Valor real (Diferença para alterar os pesos)
#      78         dW2 = 1/m * np.dot(dZ2, A1.T) #Quanto eu preciso alterar os pesos de W2
#      79
#
# KeyboardInterrupt:

# %%
class Total:  
#Iniciar os parametros da rede    
    def __init__(self,x,y,hidden_neurons,lr,num_iteration):


        self.x = x
        self.y = y
        self.hidden_neurons = hidden_neurons
        self.lr = lr
        self.num_iteration = num_iteration


    #Arquitetura da rede
    def arq_rede(self):
        n_x = self.x.shape[0]
        n_h = self.hidden_neurons
        n_y = self.y.shape[0]
        arquite = {'n_x': n_x, 'n_h': n_h, 'n_y': n_y}
        return(arquite)

#Inicializar pesos
    def init_pesos(self):
        n_x = self.arq_rede().get('n_x')
        n_h = self.arq_rede().get('n_h')
        n_y = self.arq_rede().get('n_y')
        W1 = np.full((n_h, n_x), np.random.uniform(0,n_h * n_x))*0.01
        W2 = np.full((n_y, n_h), np.random.uniform(0,n_h * n_x))*0.01
        params_pesos = {'W1': W1, 'W2': W2}
        return(params_pesos)


#Forward Propagation

    def forward_prop(self):

        n_h = self.arq_rede().get('n_x')
        n_y = self.arq_rede().get('n_y')

        W1 = self.init_pesos().get('W1')
        W2 = self.init_pesos().get('W2')


        Z1 = np.dot(W1,self.x) #Multiplicação entre camada de entrada X Pesos
        A1 = sig(Z1) #Função Sigmoide do resultado da Multiplicação entre Camada de entrada X Pesos (Camada Oculta)
        Z2 = np.dot(W2,A1) #Multiplicação entre o resultado da sigmoide X pesos da camada intermediaria (Entre camada oculta e saida)
        prev1 = sig(Z2) #Função Sigmoide no resultado da multiplicação de Z2 (Camada de saida)
        cache = {'Z1':W1, 'A1':A1, 'Z2':Z2, 'prev1':prev1}
        return (cache)

#Cost Function

    def funcao_custo(self):

        m = self.y.shape[1]
        prev1 = self.forward_prop().get('prev1')
        target =self.y.values[0]

        self.cost = sum(sum((target - prev1)**2))/m
        return (self.cost)

#Backpropagation
    def backwardPropagation(self):

        m = self.x.shape[1]

        n_x = self.arq_rede().get('n_x')
        n_h = self.arq_rede().get('n_h')
        n_y = self.arq_rede().get('n_y')

        prev1 = self.forward_prop().get('prev1')
        A1 = self.forward_prop().get('A1')
        W2 = self.init_pesos().get('W2')
        target =self.y.values[0]



        dZ2 = (prev1 - target) #Valor previsto - Valor real (Diferença para alterar os pesos)
        dW2 = 1/m * np.dot(dZ2, A1.T) #Quanto eu preciso alterar os pesos de W2


        dZ1 = np.dot(W2.T,dZ2) * (1 - A1**2)#Mudança que ocorre na camada intermediaria para camada de entrada em funçao de DZ2
        dW1 = 1/m * np.dot(dZ1 , self.x.T) #Quanto eu preciso alterar os pesos de W1 em função de W2


        grads = {'dW1':dW1, 'dW2':dW2}


        return(grads)

#Atualizar os pesos
    def updateParameters(self):

        W1 = self.init_pesos().get('W1')
        W2 = self.init_pesos().get('W2')

        dW1 = self.backwardPropagation().get('dW1')
        dW2 = self.backwardPropagation().get('dW2')


        W1 = W1 - self.lr * dW1 #Atualizar peso W1
        W2 = W2 - self.lr * dW2 #Atualizar peso W2

        updated_pesos = {'W1': W1, 'W2': W2}



        return(updated_pesos)

#loop

    def loop(self):
        arquit_rede = Total.arq_rede(self)
        init_params = Total.init_pesos(self)
        forw = Total.forward_prop(self)
        cost = Total.funcao_custo(self)
        
        
      
        cost_history = []
        
        while cost > 18:
            fwd_prop = Total.forward_prop(self)
            
            cost = Total.funcao_custo(self)
            
            back_prop = Total.backwardPropagation(self)
            
            update_params = Total.updateParameters(self)
            
            init_params = update_params
            
            cost_history.append(cost)
            
       
            
            print(cost)

# %%
#Inicialização dos hiperparametros

inte = Total(x = X_train,y = y_train,hidden_neurons =310,lr = 0.001, num_iteration=10)
inte

# %%
inte.loop()
# Out:
# 24.64362540717464
# 24.891496173493636
# 24.79974894227954
# 24.88285482128653
# 22.3467381590706
# 24.90505703017914
# 24.066877693248554
# 24.653851556808597
# 24.254006336031274
# 24.682423175435456
# 24.872859354168323
# 24.36828004430175
# 24.948095135794667
# 24.881182626924918
# 24.577298817720582
# 24.887338318669002
# 24.833712055479374
# 24.866484226751652
# 24.542555746300078
# 24.80769720292598
# 24.893406821330355
# 24.76107353848414
# 24.8744701876421
# 24.91392590198084
# 24.371430986732893
# 24.4882950022202
# 23.96984612042513
# 24.894933776025635
# 24.175406848446883
# 22.369742740189768
# 24.87509103989681
# 24.801130215443788
# 24.871811682396324
# 24.075666037385854
# 24.457688454653454
# 24.869430491433583
# 24.82789841187855
# 24.826734122685547
# 24.84385297245852
# 24.523434895021275
# 24.82818285984791
# 24.875402145320972
# 24.817763234872185
# 24.706300879129916
# 24.5847350728754
# 24.710606366860787
# 24.891009278920702
# 24.885736474462636
# 24.707602512877763
# 24.904584914362214
# 24.88398350333127
# 24.374145317747125
# 23.61478555002185
# 24.509866582809646
# 24.84315757436535
# 24.812562770061692
# 24.910876261341528
# 24.8162910580145
# 24.834837121447986
# 24.71514450393686
# 24.619221232793333
# 24.81813072457299
# 24.80450392736679
# 23.211121789080263
# 24.865416868580773
# 24.635727107572446
# 23.49830757710762
# 24.59544871146806
# 24.08825736514954
# 24.79114628439034
# 24.219208431249967
# 24.85548008869816
# 23.458566640919507
# 23.50010269832434
# 24.029927024723378
# 24.743652836537432
# 24.879279573431205
# 24.84122750349933
# 24.47726597733952
# 24.67795376042092
# 24.865520923922272
# 24.920973454137382
# 24.910833165523137
# 24.858878955205597
# 24.812794329013073
# 22.3467381590706
# 24.83347878472591
# 24.875570303759492
# 24.893197835878738
# 23.801874833360113
# 24.492161200810273
# 24.047937556387083
# 24.58307510415987
# 24.87154897063555
# 24.77798162601142
# 24.828475437582533
# 24.704141636873597
# 24.89575101432048
# 24.791919122698516
# 23.66714762658532
# 22.73873226079191
# 24.778180760561373
# 24.877501205298444
# 24.877137129113372
# 24.73157147976196
# 24.80800225848308
# 24.90619202374174
# 24.69515025184741
# 24.8763491563387
# 24.885332617782822
# 24.764791894983375
# 23.842000844049522
# 24.61184261983718
# 24.62534533583172
# 24.804671267345956
# 24.81275462531926
# 24.858420744466727
# 23.89042565925579
# 24.897981743764323
# 24.79522234890726
# 24.473471864299658
# 24.343065946713416
# 24.866796577533023
# 24.70513820148119
# 24.803292586186956
# 24.55738393577018
# 24.913872540661774
# 24.78529770561848
# 24.837866928488634
# 24.36484802631252
# 24.74412098522863
# 24.82498866635373
# 24.749300379343115
# 24.901881861874795
# 24.60177967128423
# 24.79422771197571
# 24.879593723491485
# 24.7632820443624
# 24.892456258233246
# 24.36853857742683
# 24.90255474160627
# 23.8037187864069
# 24.81461178841217
# 24.611210293024865
# 22.346738159643753
# 22.3865627434541
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9404/745894493.py in <module>
# ----> 1 inte.loop()
#
# ~\AppData\Local\Temp/ipykernel_9404/4187250835.py in loop(self)
#     126             back_prop = Total.backwardPropagation(self)
#     127
# --> 128             update_params = Total.updateParameters(self)
#     129
#     130             init_params = update_params
#
# ~\AppData\Local\Temp/ipykernel_9404/4187250835.py in updateParameters(self)
#      94         W2 = self.init_pesos().get('W2')
#      95
# ---> 96         dW1 = self.backwardPropagation().get('dW1')
#      97         dW2 = self.backwardPropagation().get('dW2')
#      98
#
# ~\AppData\Local\Temp/ipykernel_9404/4187250835.py in backwardPropagation(self)
#      79
#      80
# ---> 81         dZ1 = np.dot(W2.T,dZ2) * (1 - A1**2)#Mudança que ocorre na camada intermediaria para camada de entrada em funçao de DZ2
#      82         dW1 = 1/m * np.dot(dZ1 , self.x.T) #Quanto eu preciso alterar os pesos de W1 em função de W2
#      83
#
# KeyboardInterrupt:
