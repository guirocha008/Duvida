# %%
import pandas as pd
import sweetviz 
import pandas   as pd 
import numpy    as np
import seaborn as sns
import math

from matplotlib       import pyplot as plt
from sklearn import preprocessing as pp
from imblearn import combine as c
import xgboost as xgb
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
from sklearn import ensemble as en
import xgboost as xgb
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
from datetime import datetime, timedelta

# %%
hoje = datetime.today().date() - timedelta(days=1)

df = pd.read_csv('spi_matches.csv',sep=';')
df = (df[['date','team1', 'team2', 'spi1','spi2', 'prob1', 'prob2', 
          'probtie', 'proj_score1', 'proj_score2', 'score1', 'score2','2.5']])
df
# Out:
#              date             team1                team2   spi1   spi2  \
# 0      12/08/2016            Bastia  Paris Saint-Germain  51.16  85.68
# 1      12/08/2016         AS Monaco             Guingamp  68.85  56.48
# 2      13/08/2016         Hull City       Leicester City  53.57  66.81
# 3      13/08/2016     Middlesbrough           Stoke City  56.32  60.35
# 4      13/08/2016       Southampton              Watford  69.49  59.33
# ...           ...               ...                  ...    ...    ...
# 27618  10/07/2022            Santos  Atlético Goianiense  52.40  44.99
# 27619  10/07/2022         Fortaleza            Palmeiras  47.19  63.89
# 27620  10/07/2022  Atletico Mineiro            São Paulo  59.92  57.32
# 27621  10/07/2022         Querétaro               Necaxa  37.32  39.28
# 27622  10/07/2022            Cuiaba             Botafogo  40.68  41.96
#
#         prob1   prob2  probtie  proj_score1  proj_score2  score1  score2  2.5
# ...

# %%
#Antes da transforamção
df.loc[24712]
# Out:
# date             07/01/2022
# team1                Puebla
# team2          Club América
# spi1                  42.23
# spi2                  60.52
# prob1                0.2664
# prob2                0.4647
# probtie              0.2688
# proj_score1            1.03
# proj_score2            1.45
# score1                    1
# score2                    1
# 2.5                       0
# Name: 24712, dtype: object

# %%
#Antes da transforamção
df.loc[24713]
# Out:
# date                  08/01/2022
# team1          Melbourne Victory
# team2            Adelaide United
# spi1                       20.76
# spi2                       23.01
# prob1                     0.3847
# prob2                     0.3807
# probtie                   0.2346
# proj_score1                 1.48
# proj_score2                 1.47
# score1                         1
# score2                         1
# 2.5                            0
# Name: 24713, dtype: object

# %%
hoje = datetime.today().date() - timedelta(days=1)

df['date'] = pd.to_datetime(df['date'], errors='ignore')
jogos_dia = df[df['date'] == pd.to_datetime(hoje)]
df = df.loc[df['date'] <= pd.to_datetime(hoje), :]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27049 entries, 0 to 27579
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         27049 non-null  datetime64[ns]
#  1   team1        27049 non-null  object
#  2   team2        27049 non-null  object
#  3   spi1         27049 non-null  float64
#  4   spi2         27049 non-null  float64
#  5   prob1        27049 non-null  float64
#  6   prob2        27049 non-null  float64
#  7   probtie      27049 non-null  float64
#  8   proj_score1  27049 non-null  float64
#  9   proj_score2  27049 non-null  float64
#  10  score1       27049 non-null  int64
#  11  score2       27049 non-null  int64
#  12  2.5          27049 non-null  int64
# dtypes: datetime64[ns](1), float64(7), int64(3), object(2)
# memory usage: 2.9+ MB
# ...

# %%
#Após a transformação
df.loc[24712]
# Out:
# date           2022-07-01 00:00:00
# team1                       Puebla
# team2                 Club América
# spi1                         42.23
# spi2                         60.52
# prob1                       0.2664
# prob2                       0.4647
# probtie                     0.2688
# proj_score1                   1.03
# proj_score2                   1.45
# score1                           1
# score2                           1
# 2.5                              0
# Name: 24712, dtype: object

# %%
#Após a transformação
df.loc[24713]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2131, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2140, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 24713
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.iloc[24713,:]
# Out:
# date           2022-01-13 00:00:00
# team1                    Famalicao
# team2                   Belenenses
# spi1                         50.29
# spi2                         38.21
# prob1                       0.5292
# prob2                       0.2174
# probtie                     0.2534
# proj_score1                    1.5
# proj_score2                   0.86
# score1                           1
# score2                           0
# 2.5                              0
# Name: 24770, dtype: object

# %%
# Verificar se existe valores nulos
df.isnull().sum()
# Out:
# date           0
# team1          0
# team2          0
# spi1           0
# spi2           0
# prob1          0
# prob2          0
# probtie        0
# proj_score1    0
# proj_score2    0
# score1         0
# score2         0
# 2.5            0
# dtype: int64

# %%
len(df)
# Out:
# 27049

# %%
df['resultado'] = ''

for i in range(len(df)):
    if df.loc[i, 'score1'] > df.loc[i, 'score2']:
        df.loc[i, 'resultado'] = 'H'
    elif df.loc[i, 'score1'] < df.loc[i, 'score2']:
        df.loc[i, 'resultado'] = 'A'
    else:
        df.loc[i, 'resultado'] = 'D'
        
# Dados de Pontos
def Pontos_H (Result_FT):
    if Result_FT == 'H':
        Pontos = 3
    elif Result_FT == 'D':
        Pontos = 1
    else:
        Pontos = 0
    return Pontos

def Pontos_A (Result_FT):
    if Result_FT == 'A':
        Pontos = 3
    elif Result_FT == 'D':
        Pontos = 1
    else:
        Pontos = 0
    return Pontos

df['Total_Goals_FT'] = df['score1'] + df['score2']

df['Pontos_H'] = df.apply(lambda row: Pontos_H(row['resultado']), axis=1)

df['Pontos_A'] = df.apply(lambda row: Pontos_A(row['resultado']), axis=1)

df['Over05_FT'] = df.apply(lambda row: 1 if (row['Total_Goals_FT'] > 0) else 0, axis=1) 

df['Over15_FT'] = df.apply(lambda row: 1 if (row['Total_Goals_FT'] > 1) else 0, axis=1) 

df['Over25_FT'] = df.apply(lambda row: 1 if (row['Total_Goals_FT'] > 2) else 0, axis=1) 

df['BTTS'] = df.apply(lambda row: 1 if (row['score1'] > 0 and row['score2'] > 0) else 0, axis=1) 

df['Porc_Over05FT_Home'] = (df.groupby('team1')['Over05_FT'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True) * 100)
df['Porc_Over05FT_Away'] = (df.groupby('team2')['Over05_FT'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True) * 100)

df['Porc_Over15FT_Home'] = (df.groupby('team1')['Over15_FT'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True) * 100)
df['Porc_Over15FT_Away'] = (df.groupby('team2')['Over15_FT'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True) * 100)

df['Porc_Over25FT_Home'] = (df.groupby('team1')['Over25_FT'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True) * 100)
df['Porc_Over25FT_Away'] = (df.groupby('team2')['Over25_FT'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True) * 100)

df['Porc_BTTS_Home'] = (df.groupby('team1')['BTTS'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True) * 100)
df['Porc_BTTS_Away'] = (df.groupby('team2')['BTTS'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True) * 100)

# Média
df['Media_Pontos_H'] = df.groupby('team1')['Pontos_H'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True)
df['Media_Pontos_A'] = df.groupby('team2')['Pontos_A'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True)

# Desvio Padrão
df['DP_Pontos_H'] = df.groupby('team1')['Pontos_H'].rolling(window=5, min_periods=1).std().reset_index(0,drop=True)
df['DP_Pontos_A'] = df.groupby('team2')['Pontos_A'].rolling(window=5, min_periods=1).std().reset_index(0,drop=True)

# Coeficiente de Variação
df['CV_Pontos_H'] = df['DP_Pontos_H'] / df['Media_Pontos_H']
df['CV_Pontos_A'] = df['DP_Pontos_A'] / df['Media_Pontos_A']

# Estatísticas de Gols

# Média
df['Media_Gols_Feitos_Home'] = df.groupby('team1')['score1'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True)
df['Media_Gols_Sofridos_Home'] = df.groupby('team1')['score2'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True)

df['Media_Gols_Feitos_Away'] = df.groupby('team2')['score2'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True)
df['Media_Gols_Sofridos_Away'] = df.groupby('team2')['score1'].rolling(window=5, min_periods=1).mean().reset_index(0,drop=True)

# Desvio Padrão
df['DP_Gols_Feitos_Home'] = df.groupby('team1')['score1'].rolling(window=5, min_periods=1).std().reset_index(0,drop=True)
df['DP_Gols_Sofridos_Home'] = df.groupby('team1')['score2'].rolling(window=5, min_periods=1).std().reset_index(0,drop=True)

df['DP_Gols_Feitos_Away'] = df.groupby('team2')['score2'].rolling(window=5, min_periods=1).std().reset_index(0,drop=True)
df['DP_Gols_Sofridos_Away'] = df.groupby('team2')['score1'].rolling(window=5, min_periods=1).std().reset_index(0,drop=True)

# Coeficiente de Variação
df['CV_Gols_Feitos_Home'] = (df['DP_Gols_Feitos_Home'] / df['Media_Gols_Feitos_Home'])
df['CV_Gols_Sofridos_Home'] = (df['DP_Gols_Sofridos_Home'] / df['Media_Gols_Sofridos_Home'])

df['CV_Gols_Feitos_Away'] = (df['DP_Gols_Feitos_Away'] / df['Media_Gols_Feitos_Away'])
df['CV_Gols_Sofridos_Away'] = (df['DP_Gols_Sofridos_Away'] / df['Media_Gols_Sofridos_Away'])

treino = df[df['date'] < pd.to_datetime(hoje)]

treino.drop([ 'Over05_FT', 'Over15_FT', 'BTTS', 'season','resultado'], axis=1, inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9780\1020128797.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['resultado'] = ''
# C:\Users\User\AppData\Local\Temp\ipykernel_9780\1020128797.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total_Goals_FT'] = df['score1'] + df['score2']
# C:\Users\User\AppData\Local\Temp\ipykernel_9780\1020128797.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df
# Out:
#             date                   team1                       team2   spi1  \
# 0     2016-12-08                  Bastia         Paris Saint-Germain  51.16
# 1     2016-12-08               AS Monaco                    Guingamp  68.85
# 2     2016-08-13               Hull City              Leicester City  53.57
# 3     2016-08-13           Middlesbrough                  Stoke City  56.32
# 4     2016-08-13             Southampton                     Watford  69.49
# ...          ...                     ...                         ...    ...
# 27575 2022-04-07                 Pachuca                   Querétaro  56.03
# 27576 2022-04-07      Los Angeles Galaxy             Montreal Impact  42.92
# 27577 2022-06-07  Pittsburgh Riverhounds                 Indy Eleven  21.65
# 27578 2022-06-07         Detroit City FC           Hartford Athletic  12.94
# 27579 2022-06-07       New Mexico United  Rio Grande Valley FC Toros  21.61
#
# ...

# %%
df.loc[24714]
